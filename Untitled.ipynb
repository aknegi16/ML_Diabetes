# %%
import pandas as pd
import numpy as np
import matplotlib as mp
from matplotlib import pyplot as plt
from sklearn.linear_model import LogisticRegression

# %%
data=pd.read_csv('data/Pima_Indian_diabetes.csv')

# %%
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin        BMI  \
# 0            6.0    148.0           72.0           35.0      0.0  33.600000
# 1            1.0     85.0           66.0           29.0      0.0  26.600000
# 2            8.0    183.0           64.0            0.0      0.0  23.300000
# 3            1.0     89.0           66.0           23.0     94.0  19.179925
# 4            0.0    137.0           40.0           35.0    168.0  43.100000
# ..           ...      ...            ...            ...      ...        ...
# 763         10.0    101.0           76.0           48.0    180.0  32.900000
# 764          2.0    122.0           70.0           27.0      0.0  36.800000
# 765          5.0    121.0           72.0           23.0    112.0  26.200000
# 766          1.0    126.0           60.0            0.0      0.0  30.100000
# 767          1.0     93.0           70.0           31.0      0.0  30.400000
#
#      DiabetesPedigreeFunction   Age  Outcome
# ...

# %%
import seaborn as sns

# %%
matplotlib inline

# %%
corr = data.corr()
print(corr)
sns.heatmap(corr, 
         xticklabels=corr.columns, 
         yticklabels=corr.columns)
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.089099       0.122399      -0.099514
# Glucose                      0.089099  1.000000       0.139863       0.072642
# BloodPressure                0.122399  0.139863       1.000000       0.207191
# SkinThickness               -0.099514  0.072642       0.207191       1.000000
# Insulin                     -0.096964  0.329784       0.089148       0.432670
# BMI                         -0.015430  0.179681       0.274645       0.381212
# DiabetesPedigreeFunction    -0.035988  0.124182       0.039959       0.183684
# Age                          0.461788  0.250379       0.231473      -0.126011
# Outcome                      0.194147  0.469506       0.062818       0.085366
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.096964 -0.015430                 -0.035988
# ...

# %%
data.shape
# Out:
# (768, 9)

# %%
dfTrain = data[:650]
dfTest = data[650:750]
dfCheck = data[750:]

# %%
trainLabel = np.asarray(dfTrain['Outcome'])
trainData = np.asarray(dfTrain.drop('Outcome',1))
testLabel = np.asarray(dfTest['Outcome'])
testData = np.asarray(dfTest.drop('Outcome',1))
label=data['Outcome']

# %%
colors=['red','Blue']

# %%
data.plot.scatter(x='BMI', y='Glucose',c=label,cmap=mp.colors.ListedColormap(colors))

ax = data.plot.scatter(x='Pregnancies', y='Glucose',c=label,cmap=mp.colors.ListedColormap(colors))
ax = data.plot.scatter(x='Age', y='Glucose',c=label,cmap=mp.colors.ListedColormap(colors))
ax = data.plot.scatter(x='DiabetesPedigreeFunction', y='Glucose',c=label,cmap=mp.colors.ListedColormap(colors))
ax = data.plot.scatter(x='SkinThickness', y='Glucose',c=label,cmap=mp.colors.ListedColormap(colors))
ax = data.plot.scatter(x='Insulin', y='Glucose',c=label,cmap=mp.colors.ListedColormap(colors))

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
# Pregnancies                 742 non-null float64
# Glucose                     752 non-null float64
# BloodPressure               768 non-null float64
# SkinThickness               746 non-null float64
# Insulin                     768 non-null float64
# BMI                         757 non-null float64
# DiabetesPedigreeFunction    768 non-null float64
# Age                         749 non-null float64
# Outcome                     768 non-null int64
# dtypes: float64(8), int64(1)
# memory usage: 54.1 KB

# %%
means = np.mean(trainData, axis=0)
stds = np.std(trainData, axis=0)
trainData = (trainData - means)/stds
testData = (testData - means)/stds



# drop rows with missing values
trainData.dropna(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-a5a476d9592c> in <module>
#       7
#       8 # drop rows with missing values
# ----> 9 trainData.dropna(inplace=True)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'dropna'

# %%
diabetesCheck = LogisticRegression()
diabetesCheck.fit(trainData, trainLabel)
# Out:
# /home/akash/.local/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-882adf0d491f> in <module>
#       1 diabetesCheck = LogisticRegression()
# ----> 2 diabetesCheck.fit(trainData, trainLabel)
#
# ~/.local/lib/python3.6/site-packages/sklearn/linear_model/logistic.py in fit(self, X, y, sample_weight)
#    1530
#    1531         X, y = check_X_y(X, y, accept_sparse='csr', dtype=_dtype, order="C",
# -> 1532                          accept_large_sparse=solver != 'liblinear')
#    1533         check_classification_targets(y)
#    1534         self.classes_ = np.unique(y)
#
# ...

# %%
accuracy = diabetesCheck.score(testData, testLabel)
print("accuracy = ", accuracy * 100, "%")
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-15-68ffc37ec65f> in <module>
# ----> 1 accuracy = diabetesCheck.score(testData, testLabel)
#       2 print("accuracy = ", accuracy * 100, "%")
#
# ~/.local/lib/python3.6/site-packages/sklearn/base.py in score(self, X, y, sample_weight)
#     355         """
#     356         from .metrics import accuracy_score
# --> 357         return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#     358
#     359
#
# ~/.local/lib/python3.6/site-packages/sklearn/linear_model/base.py in predict(self, X)
#     287             Predicted class label per sample.
#     288         """
# --> 289         scores = self.decision_function(X)
#     290         if len(scores.shape) == 1:
#     291             indices = (scores > 0).astype(np.int)
#
# ...
